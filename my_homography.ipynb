# %% [markdown]
# <a href="https://colab.research.google.com/github/etgins/Computer-Vision-Alg-App-HW/blob/main/my_homography.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2
import scipy
from matplotlib import pyplot as plt

# %%
import os
DATA_PATH = "/content/drive/MyDrive/Colab Notebooks/046746/HW4/data/"
MY_DATA_PATH = '/content/drive/MyDrive/Colab Notebooks/046746/HW4/my_data/'
OUTPUT_PATH = '/content/drive/MyDrive/Colab Notebooks/046746/HW4/output/'
os.makedirs(OUTPUT_PATH, exist_ok=True)

# DATA_PATH = './data/'
# MY_DATA_PATH = './my_data/'
# OUTPUT_PATH = './output/'
# os.makedirs(OUTPUT_PATH, exist_ok=True)

# %%
#Add imports if needed:
    # """
    # Your code here
    # """
#end imports

# %%
# #Add extra functions here:
#     """
#     Your code here
#     """
# #Extra functions end

# %%
# HW functions:

# %%
# Inputs: 
#         - im1 and im2 are two 2D grayscale images.
#         - N is the number of corrosponding points you want to extract.
# Output: 
#         - p1 and p2 should be 2 x N matrices of corresponding (x,y)^T coordinates between two images.

def getPoints(im1,im2,N):
    fig, axes = plt.subplots(1,2, figsize=(20,10))
    axes[0].imshow(cv2.cvtColor(im1, cv2.COLOR_BGR2RGB))
    axes[1].imshow(cv2.cvtColor(im2, cv2.COLOR_BGR2RGB))    
    axes[0].set_xticks([])
    axes[1].set_xticks([])
    axes[0].set_yticks([])
    axes[1].set_yticks([])
    points_list = np.asarray(plt.ginput(n=2*N,
               timeout=0, # will never timeout
               show_clicks=True)) # show a red cross at the location of each click.              
              # more defaults: mouse_add=<MouseButton.LEFT: 1>, mouse_pop=<MouseButton.RIGHT: 3>, mouse_stop=<MouseButton.MIDDLE: 2>)
              # Returns list of tuples : A list of the clicked (x, y) coordinates.
    print(points_list.shape)
    # return p1,p2

# %%
def computeH(p1, p2):
    assert (p1.shape[1] == p2.shape[1])
    assert (p1.shape[0] == 2)
    # """
    # Your code here
    # """
    return H2to1

def warpH(im1, H, out_size):
    # """
    # Your code here
    # """
    return warp_im1

def imageStitching(img1, wrap_img2):
    # """
    # Your code here
    # """
    return panoImg

def ransacH(matches, locs1, locs2, nIter, tol):
    # """
    # Your code here
    # """
    return bestH

def getPoints_SIFT(im1,im2):
    # """
    # Your code here
    # """
    return p1,p2

# %%
if __name__ == '__main__':
    print('my_homography')
    im1 = cv2.imread(DATA_PATH + 'incline_L.png')
    im2 = cv2.imread(DATA_PATH + 'incline_R.png')
    # """
    # Your code here
    # """
    getPoints(im1,im2,10)
# Out:
# my_homography
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-646f43745792> in <module>()
#       6     # Your code here
#       7     # """
# ----> 8     getPoints(im1,im2,10)
#
# <ipython-input-5-3a7029c8b073> in getPoints(im1, im2, N)
#      16     points_list = np.asarray(plt.ginput(n=2*N,
#      17                timeout=0, # will never timeout
# ---> 18                show_clicks=True)) # show a red cross at the location of each click.
#      19               # more defaults: mouse_add=<MouseButton.LEFT: 1>, mouse_pop=<MouseButton.RIGHT: 3>, mouse_stop=<MouseButton.MIDDLE: 2>)
#      20               # Returns list of tuples : A list of the clicked (x, y) coordinates.
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/pyplot.py in ginput(n, timeout, show_clicks, mouse_add, mouse_pop, mouse_stop)
# ...
